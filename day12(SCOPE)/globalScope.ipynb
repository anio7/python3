# %% [markdown]
# day12 we learn about local scope and global scope

# %%
#global scope
enemies = 1


def scope():
    #to call a global variable in a local scope, you have to explicitly say scope
    global enemies
    enemies += 2
    print(enemies)

scope()
print(enemies)
# Out:
# 3
# 3

# %%
enemies = 1
def incEnem(enemy): 
   return enemy + 1

enemies = incEnem(enemies) 
print(incEnem(enemies))
# Out:
# 3

# %% [markdown]
# constants are usually in all caps. You usually would not change constant values.

# %%
CONSTS = 0
CONSTS = 1
print(CONSTS)
# Out:
# 1

# %%
lives = 7
while lives:
    lives -=1
print(lives)
# Out:
# 0
