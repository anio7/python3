# %% [markdown]
# A Higher Order Function is a function that can work with other functions. Most cases we use the function as a argument.
#
# An INSTANCE is an example of an OBJECT. Their ATTRIBUTES of different
