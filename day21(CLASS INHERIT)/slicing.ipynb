# %% [markdown]
# Slicing allows you to slice or retrieve a piece of data from a list,tuple or dictionary
# my_slice[start:finish:step]
# my_slice[2:] - from index 2 to the end
# my_slice[:5] - from the start to the finish
# my_slice[-1] - last index
# my_slice[::-1] - print in reverse with last slice first.
