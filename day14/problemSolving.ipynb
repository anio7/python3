# %% [markdown]
# Always break down the problem into smaller problems.
#
# ask questions of does it need variables, conditionals, loops and functions ....
#
# then create and test each of them alone the way while writing the program.che
