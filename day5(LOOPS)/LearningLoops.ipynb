# %% [markdown]
# for loops - (used for printing out items one by one)
#
# for loops are best for list.
# for item in list_of_items: --> this reminds me just like javascript! using for ..in.
# #do something
#
# to better understand this think of saying for item index in list, print the item/value at that index.
#
# Another form of the for loop is range. Which prints the number between a and b excluding b. Step is the number it steps by.
# for number in range(a,b,step):
# print(number)
#
# P.S - if you iterate through a string and concatenate to a empty list it splits the string into a list of strings.
#       if you iterate through a list and concatenate to a empty string it joins the list and becomes a string
#
# you can also you:
# for i in range(0, varName)
# #do something
#
# there is also the variables that are created to hold intermediate values
#
# sum = 0
# for i in range(0,10):
# sum += i
#
# for char in range(0,varNum):
# word += random.choice(var)

# %% [markdown]
# Learning loops can be fun - for loop using for ...in, for list we have for....in range(a,b,step). We also have while loops where the condition usually comes first meaning it is true. You can only loop through a SEQUENCE of strings, list or dictionary where i is stands for index.
#
# for i in iteration_target:
#     #do something
#
# for i in range(a,b, step)
#
# for condition:
#     #do something
#
# condition
# while condition(is true):
#     #do something

# %%
word2 = ""
word = "hello World"
for i in word:
    print(i, end ="")#this prints the iteration in the loop
    
#add results of iteration into empty variable using short hand assignment (+=) method
for i in word:    
    word2 +=i
print("\n",word2) #this prints the result of the loop because its outside the indentation.
# Out:
# hello World
#  hello World

# %% [markdown]
# Then there are nested loop situations...where a condition or a loop is inside or nested in another loop.
#
# for i in iteration_target:
#     for i in iteration_target: / if i ==/<= / >= var:
#         do something.
#
# for i in iteration_target:
#     do something
# else:
#     do something

# %%
num = [1,2,3,4,5,6,7]
maxNum = 0
for i in num:
    if i > maxNum: #nested if statement inside a for loop
        maxNum = i
print(maxNum)
# Out:
# 7

# %% [markdown]
# Last we have for ... in range(start, stop, step) which starts iterating from the start but stop at the stop not including the stop, and step value.

# %%
word = "hello"
for i in range(0,5):
    print(f"{i} = {word[i]}")
# Out:
# 0 = h
# 1 = e
# 2 = l
# 3 = l
# 4 = o
