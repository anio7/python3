# %% [markdown]
# This lesson is about functions with outputs

# %%
def add(a,b):
    result = a + b
    return result

print(add(2,3))
# Out:
# 5

# %%
def format_name(f_name,l_name):
    titfName,titlName = f_name.title(),l_name.title()
    print(titfName,titlName)

format_name(f_name="anderson",l_name="crosbie")
# Out:
# Anderson Crosbie

# %% [markdown]
# There is also an empty return using an if statement inside of a function

# %%
def year(year):
    if year % 4 == 0:
        #in order to get the return printed it must be explicitly called using print().  
        return
    else:
        #this case we use multiple return statements 
        return "not leap"  
print(year(2001))
# Out:
# not leap

# %% [markdown]
# You can store a function as a variable but you can't add the parentheses, only the name of the function. To trigger this function we then use the parentheses after including the parameters and arguments!.

# %%
year_ = year
print(year_())
# Out:
# not leap

# %% [markdown]
# Recursion is calling a function within itself. What it does is it continues to call itself until the user chooses something else.

# %%
def greet():
    print("do something")
    greet()
#running this example causes an infinite loop!
#greet()
